# %% [markdown]
# <a href="https://colab.research.google.com/github/arlo0814/colab-playground/blob/main/circuits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using Schemdraw

# %% [markdown]
# [schemdraw documentation](https://schemdraw.readthedocs.io/en/stable)

# %%
# install schemdraw
# !pip install schemdraw[matplotlib]
# Out:
# Collecting schemdraw[matplotlib]
#   Downloading schemdraw-0.20-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.11/dist-packages (from schemdraw[matplotlib]) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->schemdraw[matplotlib]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->schemdraw[matplotlib]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->schemdraw[matplotlib]) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->schemdraw[matplotlib]) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->schemdraw[matplotlib]) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->schemdraw[matplotlib]) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->schemdraw[matplotlib]) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->schemdraw[matplotlib]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->schemdraw[matplotlib]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4->schemdraw[matplotlib]) (1.17.0)
# Downloading schemdraw-0.20-py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.9/151.9 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: schemdraw
# Successfully installed schemdraw-0.20

# %% [markdown]
# Simple series connection

# %%
import schemdraw
import schemdraw.elements as elm

schemdraw.theme('monokai') # comment out to remove style

with schemdraw.Drawing():
    # 3 resistors with labels
    R1 = elm.Resistor().label('$R_1$\n10Ω')
    R2 = elm.Resistor().down().label('$R_2$\n50Ω', loc='bottom')
    R3 = elm.Resistor().left().label('$R_3$\n100Ω', loc='bottom')
    # source
    V = elm.SourceV().up().label(' V  \n20V')
    # current
    elm.LoopCurrent([R1, R2, R3, V], direction='cw').label('$I_T$')

# %%
import schemdraw
import schemdraw.elements as elm

schemdraw.theme('monokai') # comment out to remove style

with schemdraw.Drawing() as d:
    # 3 resistors with labels
    L1 = elm.Line()
    elm.Dot()
    d.push()
    R1 = elm.Resistor().down().label('$R_1$\n100Ω', loc='bottom')
    d.pop()
    elm.Line()
    elm.Dot()
    d.push()
    R2 = elm.Resistor().down().label('$R_2$\n200Ω', loc='bottom')
    d.pop()
    elm.Line()
    elm.Dot()
    d.push()
    R3 = elm.Resistor().down().label('$R_3$\n600Ω', loc='bottom')
    elm.Dot()
    elm.Line().left()
    elm.Dot()
    elm.Line()
    elm.Dot()
    L6 = elm.Line()
    # source
    V = elm.SourceV().up().label(' V  \n60V')
    # current
    elm.LoopCurrent([L1, R1, L6, V],direction='cw').label('$I_T$')
